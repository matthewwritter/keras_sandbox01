# %% [markdown]
# # Get the data

# %% [raw]
# ! cp ../full_hn_usernames/data/indexed.h5 data

# %% [raw]
# ! cp ../full_hn_usernames/data/w2v_weights_and_word_index_mapping.h5 data

# %% [markdown]
# # Build model

# %%
# %matplotlib inline

# %%
# %run mnist_example.py -w vae_cnn_mnist.h5
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 64)     18496       conv2d_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 3136)         0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           50192       flatten_2[0][0]
# ...

# %% [markdown]
# # Unwrapping for use with HN Usernames

# %%
# %run hn_comments_vae.py -t
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# encoder_input (InputLayer)   (None, 300)               0
# _________________________________________________________________
# encoder (Model)              [(None, 2), (None, 2), (N 43844388
# _________________________________________________________________
# decoder (Model)              (None, 30000)             3874320
# ...
# Total params: 47,718,708
# Trainable params: 7,718,708
# Non-trainable params: 40,000,000
# _________________________________________________________________
# Epoch 1/10
# 37054/37054 [==============================] - 11s 298us/step - loss: 2965379534.0048
# Epoch 2/10
# 37054/37054 [==============================] - 10s 283us/step - loss: 30.3462
# Epoch 3/10
# 37054/37054 [==============================] - 11s 284us/step - loss: 310.8548
# Epoch 4/10
# ...

# %% [markdown]
# # Apply Trained Model
